# %%
import pandas as pd
import json
import statsmodels.formula.api as smf
import re
import statsmodels.regression.linear_model as sm


with open('result2.json') as f:
    data = json.load(f)

with open('studios.txt') as f:
    studios = []
    for s in f:
        studios.append(s.strip())

# %%
df = pd.DataFrame(data).drop(['download_latency', 'download_slot','download_timeout', 'depth'], axis=1)
df.shape
# Out:
# (2127, 15)

# %%
df = df.applymap(lambda x: np.nan if ((str(x).lower() == 'nan') or (str(x) == 'n/a')) else x)

# %%
# Genre
genre_pre = df.set_index('title').genre.str.split(',', expand=True).stack().reset_index(level=1, drop=True).to_frame('genre')
dummy_genre = pd.get_dummies(genre_pre, prefix='g', columns=['genre']).groupby(level=0).sum().reset_index()
col = dummy_genre.columns.str.replace(' ', '')
dummy_genre.columns = col

# %%
# Language
language_pre = df.set_index('title').language.str.split(',', expand=True).stack().reset_index(level=1, drop=True).to_frame('language')
dummy_language = pd.get_dummies(language_pre, prefix='l', columns=['language']).groupby(level=0).sum().reset_index()

# %%
# MPAA
df.mpaa = df_clean.mpaa.str.replace('-', '_')
df.mpaa = df_clean.mpaa.str.replace('PG_13', 'PGthirt')
df.mpaa = df_clean.mpaa.str.replace('NC_17', 'NC')

mpaa_pre = df.set_index('title').mpaa.str.split(',', expand=True).stack().reset_index(level=1, drop=True).to_frame('mpaa')
dummy_mpaa = pd.get_dummies(mpaa_pre, prefix='m', columns=['mpaa']).groupby(level=0).sum().reset_index()

# %%
# Directors
director_pre = df.set_index('title').director.str.split(',', expand=True).stack().reset_index(level=1, drop=True).to_frame('director')
dummy_director = pd.get_dummies(director_pre, prefix='d', columns=['director']).groupby(level=0).sum().reset_index()

# %%
# Country
country_pre = df.set_index('title').country.str.split(',', expand=True).stack().reset_index(level=1, drop=True).to_frame('country')
dummy_country = pd.get_dummies(country_pre, prefix='d', columns=['country']).groupby(level=0).sum().reset_index()

# %%
df_clean = df.merge(dummy_genre)
df_clean = df_clean.merge(dummy_language)
df_clean = df_clean.merge(dummy_mpaa)
df_clean = df_clean.merge(dummy_country)
#df_clean = df_clean.merge(dummy_director)
df_clean.shape
# Out:
# (2126, 181)

# %%
# USD conversions
# Euro 
# Pound (check year conversion) grab year and exchange rate

# Clean
df_clean.lifetime = df_clean.lifetime.str.replace('$', '').str.replace(',', '')
df_clean.opening = df_clean.opening.str.replace('$', '').str.replace(',', '')

df_clean.mpaa.unique()

# clean budget
# Out:
# array(['PGthirt', 'PG', 'R', 'NC', 'PG_'], dtype=object)

# %%
df[df_clean.mpaa == 'PG_'].iloc[0].mpaa = 'PGthirt' # Fix an odd value
# Out:
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-339-43b5d946c929> in <module>()
# ----> 1 df[df_clean.mpaa == 'PG_'].iloc[0].mpaa = 'PGthirt' # Fix an odd value
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2054         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2055             # either boolean or fancy integer index
# -> 2056             return self._getitem_array(key)
#    2057         elif isinstance(key, DataFrame):
#    2058             return self._getitem_frame(key)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2094             # check_bool_indexer will throw exception if Series key cannot
#    2095             # be reindexed to match DataFrame rows
# -> 2096             key = check_bool_indexer(self.index, key)
#    2097             indexer = key.nonzero()[0]
#    2098             return self.take(indexer, axis=0, convert=False)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in check_bool_indexer(ax, key)
#    1937         mask = isnull(result._values)
#    1938         if mask.any():
# -> 1939             raise IndexingError('Unalignable boolean Series provided as '
#    1940                                 'indexer (index of the boolean Series and of '
#    1941                                 'the indexed object do not match')
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match

# %%
df_clean.rating = df_clean.rating.apply(float)
df_clean.runtime = df_clean.runtime.apply(float)

# %%
# Temporary, need to do currency conversions, or scrap from box office mojo
#df_clean.budget = df_clean.opening.str.replace('$', '')
#df_clean.budget = df_clean.opening.apply(lambda x: x if x.isdigit() else np.nan)
df_clean.budget[:5]
# Out:
# 0     $20000000
# 1    $250000000
# 2      $6500000
# 3    $110000000
# 4    $108000000
# Name: budget, dtype: object

# %%
# df_clean[df_clean.budget.apply(lambda x: str(x)[0]) != '$'].sort_values(by='budget')

# %%
df_clean['currency'] = df_clean.budget.apply(lambda x: re.search(r'([^\d]+)([^(\s]+)', str(x))[1].strip() if (x is not np.nan) else np.nan)

# %%
df_clean_dropped = df_clean.dropna(how='any')
list(df_clean_dropped.columns)
# Out:
# ['budget',
#  'country',
#  'director',
#  'genre',
#  'language',
#  'lifetime',
#  'mojo_url',
#  'mpaa',
#  'opening',
#  'rating',
#  'rating_count',
#  'runtime',
#  'title',
#  'url',
#  'year',
#  'g_Action',
#  'g_Adventure',
#  'g_Animation',
#  'g_Biography',
#  'g_Comedy',
#  'g_Crime',
#  'g_Drama',
#  'g_Family',
#  'g_Fantasy',
#  'g_History',
#  'g_Horror',
#  'g_Music',
#  'g_Musical',
#  'g_Mystery',
#  'g_Romance',
#  'g_Sci-Fi',
#  'g_Sport',
#  'g_Thriller',
#  'g_War',
#  'g_Western',
#  'l_',
#  'l_ Ancient (to 1453)',
#  'l_Aboriginal',
#  'l_Acholi',
#  'l_Afrikaans',
#  'l_Albanian',
#  'l_Algonquin',
#  'l_American Sign Language',
#  'l_Apache languages',
#  'l_Arabic',
#  'l_Aramaic',
#  'l_Armenian',
#  'l_Bambara',
#  'l_Bengali',
#  'l_Berber languages',
#  'l_Bulgarian',
#  'l_Burmese',
#  'l_Cantonese',
#  'l_Catalan',
#  'l_Chinese',
#  'l_Croatian',
#  'l_Czech',
#  'l_Danish',
#  'l_Dari',
#  'l_Dutch',
#  'l_Egyptian (Ancient)',
#  'l_English',
#  'l_Esperanto',
#  'l_Estonian',
#  'l_Filipino',
#  'l_Finnish',
#  'l_Flemish',
#  'l_French',
#  'l_Georgian',
#  'l_German',
#  'l_Greek',
#  'l_Greenlandic',
#  'l_Hawaiian',
#  'l_Hebrew',
#  'l_Hindi',
#  'l_Hmong',
#  'l_Hungarian',
#  'l_Ibo',
#  'l_Icelandic',
#  'l_Indonesian',
#  'l_Irish',
#  'l_Italian',
#  'l_Japanese',
#  'l_Japanese Sign Language',
#  'l_Khmer',
#  'l_Kirundi',
#  'l_Klingon',
#  'l_Korean',
#  'l_Latin',
#  'l_Lingala',
#  'l_Mandarin',
#  'l_Maori',
#  'l_Maya',
#  'l_Mende',
#  'l_Mongolian',
#  'l_Navajo',
#  'l_None',
#  'l_North American Indian',
#  'l_Norwegian',
#  'l_Nyanja',
#  'l_Old English',
#  'l_Panjabi',
#  'l_Pawnee',
#  'l_Persian',
#  'l_Polish',
#  'l_Portuguese',
#  'l_Pushto',
#  'l_Romanian',
#  'l_Romany',
#  'l_Russian',
#  'l_Sanskrit',
#  'l_Scottish Gaelic',
#  'l_Serbian',
#  'l_Serbo-Croatian',
#  'l_Sign Languages',
#  'l_Slovak',
#  'l_Somali',
#  'l_Southern Sotho',
#  'l_Spanish',
#  'l_Swahili',
#  'l_Swedish',
#  'l_Swiss German',
#  'l_Syriac',
#  'l_Tagalog',
#  'l_Tamil',
#  'l_Thai',
#  'l_Tibetan',
#  'l_Turkish',
#  'l_Ukrainian',
#  'l_Urdu',
#  'l_Vietnamese',
#  'l_Welsh',
#  'l_Xhosa',
#  'l_Yiddish',
#  'l_Zulu',
#  'm_NC-17',
#  'm_PG',
#  'm_PG-',
#  'm_PG-13',
#  'm_R',
#  'd_Algeria',
#  'd_Australia',
#  'd_Austria',
#  'd_Bahamas',
#  'd_Belgium',
#  'd_Brazil',
#  'd_Canada',
#  'd_Chile',
#  'd_China',
#  'd_Czech Republic',
#  'd_Denmark',
#  'd_Finland',
#  'd_France',
#  'd_Georgia',
#  'd_Germany',
#  'd_Greece',
#  'd_Hong Kong',
#  'd_Hungary',
#  'd_Iceland',
#  'd_India',
#  'd_Indonesia',
#  'd_Iran',
#  'd_Ireland',
#  'd_Israel',
#  'd_Italy',
#  'd_Japan',
#  'd_Kenya',
#  'd_Malta',
#  'd_Mexico',
#  'd_New Zealand',
#  'd_Norway',
#  'd_Palestine',
#  'd_Panama',
#  'd_Romania',
#  'd_Russia',
#  'd_South Africa',
#  'd_South Korea',
#  'd_Spain',
#  'd_Sweden',
#  'd_UK',
#  'd_USA']

# %%
X = df_clean_dropped.drop(['lifetime','budget','director', 'genre', 'language', 'mpaa', 'url', 'rating_count', 'mojo_url', 'title', 'country'], axis=1)

# %%
list(X.columns)
def generate_formula(y_str, x_l):
    result = '{} ~ '.format(y_str)
    for v in x_l:
        result += '{} + '.format(v)
    return result[:-2]

formula_name = generate_formula('lifetime', list(X.columns)).strip()
formula_name
lm1 = smf.ols(formula_name, data=X)
#fit1 = lm1.fit()
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# <ipython-input-344-296f0cf6d35b> in <module>()
#       8 formula_name = generate_formula('lifetime', list(X.columns)).strip()
#       9 formula_name
# ---> 10 lm1 = smf.ols(formula_name, data=X)
#      11 #fit1 = lm1.fit()
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     153
#     154         tmp = handle_formula_data(data, None, formula, depth=eval_env,
# --> 155                                   missing=missing)
#     156         ((endog, exog), missing_idx, design_info) = tmp
#     157
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/statsmodels/formula/formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#     312         raise PatsyError("model is missing required outcome variables")
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     163         return iter([data])
#     164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
# --> 165                                       NA_action)
#     166     if design_infos is not None:
#     167         return build_design_matrices(design_infos, data,
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      60                 "ascii-only, or else upgrade to Python 3.")
#      61     if isinstance(formula_like, str):
# ---> 62         formula_like = ModelDesc.from_formula(formula_like)
#      63         # fallthrough
#      64     if isinstance(formula_like, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in from_formula(cls, tree_or_string)
#     163         else:
#     164             tree = parse_formula(tree_or_string)
# --> 165         value = Evaluator().eval(tree, require_evalexpr=False)
#     166         assert isinstance(value, cls)
#     167         return value
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_any_tilde(evaluator, tree)
#     219
#     220 def _eval_any_tilde(evaluator, tree):
# --> 221     exprs = [evaluator.eval(arg) for arg in tree.args]
#     222     if len(exprs) == 1:
#     223         # Formula was like: "~ foo"
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in <listcomp>(.0)
#     219
#     220 def _eval_any_tilde(evaluator, tree):
# --> 221     exprs = [evaluator.eval(arg) for arg in tree.args]
#     222     if len(exprs) == 1:
#     223         # Formula was like: "~ foo"
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_minus(evaluator, tree)
#     247
#     248 def _eval_binary_minus(evaluator, tree):
# --> 249     left_expr = evaluator.eval(tree.args[0])
#     250     if tree.args[1].type == "ZERO":
#     251         return IntermediateExpr(True, tree.args[1], False,
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_minus(evaluator, tree)
#     247
#     248 def _eval_binary_minus(evaluator, tree):
# --> 249     left_expr = evaluator.eval(tree.args[0])
#     250     if tree.args[1].type == "ZERO":
#     251         return IntermediateExpr(True, tree.args[1], False,
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_plus(evaluator, tree)
#     231
#     232 def _eval_binary_plus(evaluator, tree):
# --> 233     left_expr = evaluator.eval(tree.args[0])
#     234     if tree.args[1].type == "ZERO":
#     235         return IntermediateExpr(False, None, True, left_expr.terms)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_binary_minus(evaluator, tree)
#     254         return IntermediateExpr(False, None, True, left_expr.terms)
#     255     else:
# --> 256         right_expr = evaluator.eval(tree.args[1])
#     257         terms = [term for term in left_expr.terms
#     258                  if term not in right_expr.terms]
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in eval(self, tree, require_evalexpr)
#     398                                 "'%s' operator" % (tree.type,),
#     399                                 tree.token)
# --> 400         result = self._evaluators[key](self, tree)
#     401         if require_evalexpr and not isinstance(result, IntermediateExpr):
#     402             if isinstance(result, ModelDesc):
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/patsy/desc.py in _eval_number(evaluator, tree)
#     353 def _eval_number(evaluator, tree):
#     354     raise PatsyError("numbers besides '0' and '1' are "
# --> 355                         "only allowed with **", tree)
#     356
#     357 def _eval_python_expr(evaluator, tree):
#
# PatsyError: numbers besides '0' and '1' are only allowed with **
#     lifetime ~ opening + rating + runtime + year + g_Action + g_Adventure + g_Animation + g_Biography + g_Comedy + g_Crime + g_Drama + g_Family + g_Fantasy + g_History + g_Horror + g_Music + g_Musical + g_Mystery + g_Romance + g_Sci-Fi + g_Sport + g_Thriller + g_War + g_Western + l_ + l_ Ancient (to 1453) + l_Aboriginal + l_Acholi + l_Afrikaans + l_Albanian + l_Algonquin + l_American Sign Language + l_Apache languages + l_Arabic + l_Aramaic + l_Armenian + l_Bambara + l_Bengali + l_Berber languages + l_Bulgarian + l_Burmese + l_Cantonese + l_Catalan + l_Chinese + l_Croatian + l_Czech + l_Danish + l_Dari + l_Dutch + l_Egyptian (Ancient) + l_English + l_Esperanto + l_Estonian + l_Filipino + l_Finnish + l_Flemish + l_French + l_Georgian + l_German + l_Greek + l_Greenlandic + l_Hawaiian + l_Hebrew + l_Hindi + l_Hmong + l_Hungarian + l_Ibo + l_Icelandic + l_Indonesian + l_Irish + l_Italian + l_Japanese + l_Japanese Sign Language + l_Khmer + l_Kirundi + l_Klingon + l_Korean + l_Latin + l_Lingala + l_Mandarin + l_Maori + l_Maya + l_Mende + l_Mongolian + l_Navajo + l_None + l_North American Indian + l_Norwegian + l_Nyanja + l_Old English + l_Panjabi + l_Pawnee + l_Persian + l_Polish + l_Portuguese + l_Pushto + l_Romanian + l_Romany + l_Russian + l_Sanskrit + l_Scottish Gaelic + l_Serbian + l_Serbo-Croatian + l_Sign Languages + l_Slovak + l_Somali + l_Southern Sotho + l_Spanish + l_Swahili + l_Swedish + l_Swiss German + l_Syriac + l_Tagalog + l_Tamil + l_Thai + l_Tibetan + l_Turkish + l_Ukrainian + l_Urdu + l_Vietnamese + l_Welsh + l_Xhosa + l_Yiddish + l_Zulu + m_NC-17 + m_PG + m_PG- + m_PG-13 + m_R + d_Algeria + d_Australia + d_Austria + d_Bahamas + d_Belgium + d_Brazil + d_Canada + d_Chile + d_China + d_Czech Republic + d_Denmark + d_Finland + d_France + d_Georgia + d_Germany + d_Greece + d_Hong Kong + d_Hungary + d_Iceland + d_India + d_Indonesia + d_Iran + d_Ireland + d_Israel + d_Italy + d_Japan + d_Kenya + d_Malta + d_Mexico + d_New Zealand + d_Norway + d_Palestine + d_Panama + d_Romania + d_Russia + d_South Africa + d_South Korea + d_Spain + d_Sweden + d_UK + d_USA
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ^^

# %%
sm.OLS(df_clean_dropped.lifetime, X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-335-9956e73290fc> in <module>()
# ----> 1 sm.OLS(df_clean_dropped.lifetime, X)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     629                  **kwargs):
#     630         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 631                                   hasconst=hasconst, **kwargs)
#     632         if "weights" in self._init_keys:
#     633             self._init_keys.remove("weights")
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     524             weights = weights.squeeze()
#     525         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 526                                   weights=weights, hasconst=hasconst, **kwargs)
#     527         nobs = self.exog.shape[0]
#     528         weights = self.weights
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, **kwargs)
#      93     """
#      94     def __init__(self, endog, exog, **kwargs):
# ---> 95         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#      96         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#      97
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#     210
#     211     def __init__(self, endog, exog=None, **kwargs):
# --> 212         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     213         self.initialize()
#     214
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#      61         hasconst = kwargs.pop('hasconst', None)
#      62         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 63                                       **kwargs)
#      64         self.k_constant = self.data.k_constant
#      65         self.exog = self.data.exog
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      86
#      87     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 88         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      89         # kwargs arrays could have changed, easier to just attach here
#      90         for key in kwargs:
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/statsmodels/base/data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     628     klass = handle_data_class_factory(endog, exog)
#     629     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 630                  **kwargs)
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/statsmodels/base/data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      74             self.orig_endog = endog
#      75             self.orig_exog = exog
# ---> 76             self.endog, self.exog = self._convert_endog_exog(endog, exog)
#      77
#      78         # this has side-effects, attaches k_constant and const_idx
#
# /home/jvheeswijck/anaconda3/lib/python3.6/site-packages/statsmodels/base/data.py in _convert_endog_exog(self, endog, exog)
#     469         exog = exog if exog is None else np.asarray(exog)
#     470         if endog.dtype == object or exog is not None and exog.dtype == object:
# --> 471             raise ValueError("Pandas data cast to numpy dtype of object. "
#     472                              "Check input data with np.asarray(data).")
#     473         return super(PandasData, self)._convert_endog_exog(endog, exog)
#
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).

# %%
list(df_clean.columns)
# Out:
# ['budget',
#  'country',
#  'director',
#  'genre',
#  'language',
#  'lifetime',
#  'mojo_url',
#  'mpaa',
#  'opening',
#  'rating',
#  'rating_count',
#  'runtime',
#  'title',
#  'url',
#  'year',
#  'g_Action',
#  'g_Adventure',
#  'g_Animation',
#  'g_Biography',
#  'g_Comedy',
#  'g_Crime',
#  'g_Drama',
#  'g_Family',
#  'g_Fantasy',
#  'g_History',
#  'g_Horror',
#  'g_Music',
#  'g_Musical',
#  'g_Mystery',
#  'g_Romance',
#  'g_Sci-Fi',
#  'g_Sport',
#  'g_Thriller',
#  'g_War',
#  'g_Western',
#  'l_',
#  'l_ Ancient (to 1453)',
#  'l_Acholi',
#  'l_Afrikaans',
#  'l_Albanian',
#  'l_American Sign Language',
#  'l_Apache languages',
#  'l_Arabic',
#  'l_Aramaic',
#  'l_Armenian',
#  'l_Bengali',
#  'l_Bulgarian',
#  'l_Cantonese',
#  'l_Catalan',
#  'l_Chinese',
#  'l_Czech',
#  'l_Danish',
#  'l_Dari',
#  'l_Dutch',
#  'l_Egyptian (Ancient)',
#  'l_English',
#  'l_Esperanto',
#  'l_Filipino',
#  'l_Finnish',
#  'l_Flemish',
#  'l_French',
#  'l_German',
#  'l_Greek',
#  'l_Greenlandic',
#  'l_Hawaiian',
#  'l_Hebrew',
#  'l_Hindi',
#  'l_Hungarian',
#  'l_Ibo',
#  'l_Icelandic',
#  'l_Indonesian',
#  'l_Irish',
#  'l_Italian',
#  'l_Japanese',
#  'l_Khmer',
#  'l_Klingon',
#  'l_Korean',
#  'l_Latin',
#  'l_Mandarin',
#  'l_Navajo',
#  'l_None',
#  'l_North American Indian',
#  'l_Norwegian',
#  'l_Pawnee',
#  'l_Persian',
#  'l_Polish',
#  'l_Portuguese',
#  'l_Pushto',
#  'l_Romanian',
#  'l_Romany',
#  'l_Russian',
#  'l_Sanskrit',
#  'l_Scottish Gaelic',
#  'l_Serbian',
#  'l_Serbo-Croatian',
#  'l_Sign Languages',
#  'l_Slovak',
#  'l_Somali',
#  'l_Spanish',
#  'l_Swahili',
#  'l_Swedish',
#  'l_Swiss German',
#  'l_Tagalog',
#  'l_Tamil',
#  'l_Thai',
#  'l_Turkish',
#  'l_Ukrainian',
#  'l_Urdu',
#  'l_Vietnamese',
#  'l_Welsh',
#  'l_Xhosa',
#  'l_Yiddish',
#  'd_A.J. Edwards',
#  'd_Abdellatif Kechiche',
#  'd_Adam Kassen',
#  'd_Adam McKay',
#  'd_Adam Salky',
#  'd_Adam Shankman',
#  'd_Adam Wingard',
#  'd_Ajmal Zaheer Ahmad',
#  'd_Akiva Goldsman',
#  'd_Akiva Schaffer',
#  'd_Alan Taylor',
#  'd_Albert Hughes',
#  'd_Alejandro González Iñárritu',
#  'd_Alejandro Monteverde',
#  'd_Aleksander Bach',
#  'd_Aleksey Mizgirev',
#  'd_Alessandro Carloni',
#  'd_Alex Goyette',
#  'd_Alex Gregory',
#  'd_Alex Kendrick',
#  'd_Alex Proyas',
#  'd_Alex Ranarivelo',
#  'd_Alexander Payne',
#  'd_Alexandre Aja',
#  'd_Alexandre Moors',
#  'd_Alfonso Cuarón',
#  'd_Alfonso Gomez-Rejon',
#  'd_Alister Grierson',
#  'd_Allen Coulter',
#  'd_Allen Hughes',
#  'd_Ami Canaan Mann',
#  'd_Amy Heckerling',
#  'd_Andrea Arnold',
#  'd_Andrew Bujalski',
#  'd_Andrew Dominik',
#  'd_Andrew Erwin',
#  'd_Andrew Fleming',
#  'd_Andrew Haigh',
#  'd_Andrew Jarecki',
#  'd_Andrew Levitas',
#  'd_Andrew Mogel',
#  'd_Andrew Neel',
#  'd_Andrew Niccol',
#  'd_Andrew Stanton',
#  'd_Andrey Konchalovskiy',
#  'd_Andrey Zvyagintsev',
#  'd_André Øvredal',
#  'd_Andy Fickman',
#  'd_Andy Goddard',
#  'd_Andy Muschietti',
#  'd_Andy Tennant',
#  'd_Ang Lee',
#  'd_Angelina Jolie',
#  'd_Anna Boden',
#  'd_Anne Fletcher',
#  'd_Anne Fontaine',
#  'd_Annette Haywood-Carter',
#  'd_Anthony Bell',
#  'd_Anthony Burns',
#  'd_Anthony Leonardi III',
#  'd_Anthony Russo',
#  'd_Antoine Fuqua',
#  'd_Anton Corbijn',
#  'd_Antonio Campos',
#  'd_Ari Sandel',
#  'd_Ariel Vromen',
#  'd_Arthur Muhammad',
#  'd_Asger Leth',
#  'd_Asghar Farhadi',
#  'd_Atom Egoyan',
#  'd_Ava DuVernay',
#  'd_Babak Anvari',
#  'd_Babak Najafi',
#  'd_Baltasar Kormákur',
#  'd_Barry Jenkins',
#  'd_Barry Levinson',
#  'd_Barry Sonnenfeld',
#  'd_Baz Luhrmann',
#  'd_Ben Affleck',
#  'd_Ben Falcone',
#  'd_Ben Lewin',
#  'd_Ben Smallbone',
#  'd_Ben Stiller',
#  'd_Ben Younger',
#  'd_Benh Zeitlin',
#  'd_Bennett Miller',
#  'd_Benny Chan',
#  'd_Benson Lee',
#  'd_Bernard Rose',
#  'd_Bertrand Bonello',
#  'd_Bharat Nalluri',
#  'd_Bill Condon',
#  'd_Bille Woodruff',
#  'd_Billy Dickson',
#  'd_Boaz Yakin',
#  'd_Bobby Farrelly',
#  'd_Brad Bird',
#  'd_Brad Furman',
#  'd_Brad J. Silverman',
#  'd_Brad Peyton',
#  'd_Bradley Parker',
#  'd_Brandon Dickerson',
#  'd_Breck Eisner',
#  'd_Brent McCorkle',
#  'd_Brett Ratner',
#  'd_Brian A Miller',
#  'd_Brian Baugh',
#  'd_Brian Helgeland',
#  'd_Brian Klugman',
#  'd_Brian Levant',
#  'd_Brian Percival',
#  'd_Brian Robbins',
#  'd_Bruce Beresford',
#  'd_Bruce Robinson',
#  'd_Bryan Bertino',
#  'd_Bryan Singer',
#  'd_Burr Steers',
#  'd_Byron Howard',
#  'd_Cameron Crowe',
#  'd_Camille Delamarre',
#  'd_Caradog W. James',
#  'd_Carl Rinsch',
#  'd_Carles Torrens',
#  'd_Cary Fukunaga',
#  'd_Casey Affleck',
#  'd_Casey La Scala',
#  'd_Catherine Hardwicke',
#  'd_Cedric Nicolas-Troyan',
#  'd_Chad Burns',
#  'd_Chad Hartigan',
#  'd_Chad Stahelski',
#  'd_Chan-wook Park',
#  'd_Charles Martin Smith',
#  'd_Charles Stone III',
#  'd_Charlie McDowell',
#  'd_Chris Buck',
#  'd_Chris Butler',
#  'd_Chris Fisher',
#  'd_Chris Gorak',
#  'd_Chris McCoy',
#  'd_Chris Miller',
#  'd_Chris Renaud',
#  'd_Chris Rock',
#  'd_Chris Wedge',
#  'd_Christian Ditter',
#  'd_Christian E. Christiansen',
#  'd_Christian Sesma',
#  'd_Christopher Landon',
#  'd_Christopher McQuarrie',
#  'd_Christopher Morris',
#  'd_Christopher Nolan',
#  'd_Christopher Spencer',
#  'd_Ciarán Foy',
#  'd_Clay Kaytis',
#  'd_Clea DuVall',
#  'd_Clint Eastwood',
#  'd_Cody Cameron',
#  'd_Colin Strause',
#  'd_Colin Trevorrow',
#  'd_Corbin Bernsen',
#  'd_Courtney Solomon',
#  'd_Craig Brewer',
#  'd_Craig Gillespie',
#  'd_Craig Johnson',
#  'd_Craig Moss',
#  'd_Craig Zisk',
#  'd_Craig Zobel',
#  'd_Cyrus Nowrasteh',
#  'd_D.J. Caruso',
#  'd_Damien Chazelle',
#  'd_Dan Bradley',
#  'd_Dan Fogelman',
#  'd_Dan Gilroy',
#  'd_Dan Kwan',
#  'd_Dan Mazer',
#  'd_Dan Trachtenberg',
#  'd_Daniel Barnz',
#  'd_Daniel Espinosa',
#  'd_Daniel Lee',
#  'd_Daniel Stamm',
#  'd_Danny Boyle',
#  'd_Darrell Wheat',
#  'd_Darren Aronofsky',
#  'd_Darren Doane',
#  'd_Darren Lynn Bousman',
#  'd_Daryl Wein',
#  'd_Dave Green',
#  'd_David A. Armstrong',
#  'd_David Ayer',
#  'd_David Bowers',
#  'd_David Brooks',
#  'd_David Cronenberg',
#  'd_David Dobkin',
#  'd_David E. Talbert',
#  'd_David F. Sandberg',
#  'd_David Fincher',
#  'd_David Frankel',
#  'd_David Gelb',
#  'd_David Gordon Green',
#  'd_David Grovic',
#  'd_David Hayter',
#  'd_David Hunt',
#  'd_David Koepp',
#  'd_David Lowery',
#  'd_David M. Rosenthal',
#  'd_David Mackenzie',
#  'd_David Michôd',
#  'd_David O. Russell',
#  'd_David Palmer',
#  'd_David R. Ellis',
#  'd_David Slade',
#  'd_David Soren',
#  'd_David Twohy',
#  'd_David Wain',
#  'd_David Weaver',
#  'd_David Yates',
#  'd_Dean DeBlois',
#  'd_Dean Israelite',
#  'd_Debra Granik',
#  'd_Declan Donnellan',
#  'd_Denis Villeneuve',
#  'd_Deniz Gamze Ergüven',
#  'd_Dennis Dugan',
#  'd_Dennis Gansel',
#  'd_Denzel Washington',
#  'd_Deon Taylor',
#  'd_Derek Cianfrance',
#  'd_Derick Martini',
#  'd_Destin Daniel Cretton',
#  'd_Dexter Fletcher',
#  'd_Diablo Cody',
#  'd_Diego Luna',
#  'd_Dito Montiel',
#  'd_Dominic Sena',
#  'd_Don Hall',
#  'd_Don Scardino',
#  'd_Donald Rice',
#  'd_Doug Ellin',
#  'd_Doug Liman',
#  'd_Drake Doremus',
#  'd_Drew Goddard',
#  'd_Drew Waters',
#  'd_Duke Johnson',
#  'd_Duncan Jones',
#  'd_Dustin Hoffman',
#  'd_Dustin Marcellino',
#  'd_Dylan Baker',
#  'd_Ed Gass-Donnelly',
#  'd_Edgar Wright',
#  'd_Edward Zwick',
#  'd_Eli Roth',
#  'd_Elizabeth Banks',
#  'd_Enrique Gato',
#  'd_Eran Creevy',
#  'd_Eric Darnell',
#  'd_Eric Heisserer',
#  'd_Ericson Core',
#  'd_Ernie Barbarash',
#  'd_Etan Cohen',
#  'd_Ethan Coen',
#  'd_Ethan Maniquis',
#  'd_Eugenio Derbez',
#  'd_Evan Goldberg',
#  'd_Ewan McGregor',
#  'd_F. Gary Gray',
#  'd_Farren Blackburn',
#  'd_Fede Alvarez',
#  'd_Floria Sigismondi',
#  'd_Florian Henckel von Donnersmarck',
#  'd_Francis Lawrence',
#  'd_Frank Coraci',
#  'd_Frank Miller',
#  'd_Fredrik Bond',
#  'd_Gabe Torres',
#  'd_Gabriele Muccino',
#  'd_Gareth Edwards',
#  'd_Gareth Evans',
#  'd_Garry Marshall',
#  'd_Garth Davis',
#  'd_Garth Jennings',
#  'd_Gary Fleder',
#  'd_Gary McKendry',
#  'd_Gary Ross',
#  'd_Gary Rydstrom',
#  'd_Gary Shore',
#  'd_Gavin Hood',
#  "d_Gavin O'Connor",
#  'd_Gavin Wiesen',
#  'd_Gee Malik Linton',
#  'd_Genndy Tartakovsky',
#  'd_George C. Wolfe',
#  'd_George Clooney',
#  'd_George Hickenlooper',
#  'd_George Nolfi',
#  'd_George Ratliff',
#  'd_George Tillman Jr.',
#  'd_Gil Kenan',
#  'd_Gilles Paquet-Brenner',
#  'd_Gillian Robespierre',
#  'd_Gina Prince-Bythewood',
#  'd_Glenn Ficarra',
#  'd_Gonzalo López-Gallego',
#  'd_Gore Verbinski',
#  'd_Graham Annable',
#  'd_Greg McLean',
#  'd_Greg Mottola',
#  'd_Greg Tiernan',
#  'd_Gregg Araki',
#  'd_Gregory Jacobs',
#  'd_Gregory Plotkin',
#  'd_Grégory Levasseur',
#  'd_Guillermo del Toro',
#  'd_Gus Van Sant',
#  'd_Guy Ritchie',
#  'd_Harald Zwart',
#  'd_Harold Cronk',
#  'd_Helen Hunt',
#  'd_Henry Hobson',
#  'd_Henry Joost',
#  'd_Herman Yau',
#  'd_Hilary Brougher',
#  'd_Hossein Amini',
#  'd_Huck Botko',
#  'd_Ira Sachs',
#  'd_Israel Horovitz',
#  'd_Ivan Reitman',
#  'd_J Blakeson',
#  'd_J.A. Bayona',
#  'd_J.C. Chandor',
#  'd_J.J. Abrams',
#  'd_Jacob Vaughan',
#  'd_Jacques Audiard',
#  'd_Jake Kasdan',
#  'd_Jake Paltrow',
#  'd_Jake Schreier',
#  'd_Jake Szymanski',
#  'd_Jalil Lespert',
#  'd_Jalmari Helander',
#  'd_Jamal Hill',
#  'd_James Bobin',
#  'd_James DeMonaco',
#  'd_James Franco',
#  'd_James Griffiths',
#  'd_James Gunn',
#  'd_James Mangold',
#  'd_James Marsh',
#  'd_James Mather',
#  'd_James McTeigue',
#  'd_James Ponsoldt',
#  'd_James Schamus',
#  'd_James Strong',
#  'd_James Vanderbilt',
#  'd_James Wan',
#  'd_James Watkins',
#  'd_Jared Hess',
#  'd_Jasmin Dizdar',
#  'd_Jason Friedberg',
#  'd_Jason Moore',
#  'd_Jason Reitman',
#  'd_Jason Winer',
#  'd_Jason Zada',
#  'd_Jaume Collet-Serra',
#  'd_Jay Chandrasekhar',
#  'd_Jay Duplass',
#  'd_Jay Martin',
#  'd_Jay Roach',
#  'd_Jean-Claude La Marre',
#  'd_Jean-Marc Vallée',
#  'd_Jee-woon Kim',
#  'd_Jeff Baena',
#  'd_Jeff Nichols',
#  'd_Jeff Preiss',
#  'd_Jeff Tremaine',
#  'd_Jeff Wadlow',
#  'd_Jeffrey D. Brown',
#  'd_Jeffrey G. Hunt',
#  'd_Jennifer Yuh Nelson',
#  'd_Jeremy Garelick',
#  'd_Jerome Sable',
#  'd_Jerry Jameson',
#  'd_Jerusha Hess',
#  'd_Jesse Peretz',
#  'd_Jesse V. Johnson',
#  'd_Jesse Zwick',
#  'd_Jessie Nelson',
#  'd_Jessy Terrero',
#  'd_Jill Soloway',
#  'd_Jim Jarmusch',
#  'd_Jim Mickle',
#  'd_Jim Sheridan',
#  'd_Jim Strouse',
#  'd_Jimmy Hayward',
#  'd_Jodie Foster',
#  'd_Joe Carnahan',
#  'd_Joe Cornish',
#  'd_Joe Johnston',
#  'd_Joe Nussbaum',
#  'd_Joe Swanberg',
#  'd_Joe Wright',
#  'd_Joel Edgerton',
#  'd_Joel Schumacher',
#  'd_Johannes Roberts',
#  'd_John Cameron Mitchell',
#  'd_John Carney',
#  'd_John Crowley',
#  'd_John Curran',
#  'd_John Erick Dowdle',
#  'd_John Francis Daley',
#  'd_John Gulager',
#  'd_John Hamburg',
#  'd_John Hillcoat',
#  'd_John Hyams',
#  'd_John Krasinski',
#  'd_John Krokidas',
#  'd_John Lee Hancock',
#  'd_John Luessenhop',
#  'd_John Maclean',
#  'd_John Madden',
#  'd_John Michael McDonagh',
#  'd_John Moore',
#  'd_John Pogue',
#  'd_John R. Leonetti',
#  'd_John Singleton',
#  'd_John Slattery',
#  'd_John Stockwell',
#  'd_John Wells',
#  'd_John Whitesell',
#  'd_Jon Cassar',
#  'd_Jon Favreau',
#  'd_Jon Gunn',
#  'd_Jon Hurwitz',
#  'd_Jon Kasdan',
#  'd_Jon Lucas',
#  'd_Jon M. Chu',
#  'd_Jon Stewart',
#  'd_Jon Turteltaub',
#  'd_Jon Watts',
#  'd_Jonathan Demme',
#  'd_Jonathan Hensleigh',
#  'd_Jonathan Jakubowicz',
#  'd_Jonathan Levine',
#  'd_Jonathan Liebesman',
#  'd_Jonathan Lynn',
#  'd_Jordan Vogt-Roberts',
#  'd_Jorge R. Gutiérrez',
#  'd_Jorma Taccone',
#  'd_Joseph Cedar',
#  'd_Joseph Gordon-Levitt',
#  'd_Joseph Kosinski',
#  'd_Josh Gordon',
#  'd_Josh Mond',
#  'd_Josh Radnor',
#  'd_Josh Schwartz',
#  'd_Josh Trank',
#  'd_Joshua Caldwell',
#  'd_Joshua Marston',
#  'd_Joshua Michael Stern',
#  'd_Joss Whedon',
#  'd_José Padilha',
#  'd_Judd Apatow',
#  'd_Julian Jarrold',
#  'd_Julie Delpy',
#  'd_Julie Taymor',
#  'd_Justin Chadwick',
#  'd_Justin Kurzel',
#  'd_Justin Lin',
#  'd_Justin Simien',
#  'd_Justin Tipping',
#  'd_Kar-Wai Wong',
#  'd_Kat Candler',
#  'd_Kat Coiro',
#  'd_Kathryn Bigelow',
#  'd_Keanu Reeves',
#  'd_Kees Van Oostrum',
#  'd_Kelly Fremon Craig',
#  'd_Kelly Reichardt',
#  'd_Ken Kwapis',
#  'd_Ken Scott',
#  'd_Kenneth Branagh',
#  'd_Kenneth Lonergan',
#  'd_Kent Moran',
#  'd_Kevin Asch',
#  'd_Kevin Goetz',
#  'd_Kevin Greutert',
#  'd_Kevin Macdonald',
#  'd_Kevin Munroe',
#  'd_Kevin Reynolds',
#  'd_Kevin Smith',
#  'd_Kieran Darcy-Smith',
#  'd_Kike Maíllo',
#  'd_Kim Farrant',
#  'd_Kimberly Peirce',
#  'd_Kirk De Micco',
#  'd_Kirk Jones',
#  'd_Klay Hall',
#  'd_Koan Hui',
#  'd_Kris Swanberg',
#  'd_Kyle Balda',
#  'd_Kyle Newman',
#  'd_Kyle Patrick Alvarez',
#  'd_Lana Wachowski',
#  'd_Larry Charles',
#  'd_Lars von Trier',
#  'd_Lasse Hallström',
#  'd_Lee Daniels',
#  'd_Lee Kirk',
#  'd_Lee Tamahori',
#  'd_Lee Toland Krieger',
#  'd_Leigh Janiak',
#  'd_Len Wiseman',
#  'd_Lenny Abrahamson',
#  'd_Leslye Headland',
#  'd_Li Zhang',
#  'd_Lisa Arnold',
#  'd_Lisa Cholodenko',
#  'd_Liz W. Garcia',
#  'd_Liza Johnson',
#  'd_Lone Scherfig',
#  'd_Lorene Scafaria',
#  'd_Louis Leterrier',
#  'd_Luc Besson',
#  'd_Lucky McKee',
#  'd_Luis Prieto',
#  'd_Luke Greenfield',
#  'd_Luke Scott',
#  'd_Lynn Shelton',
#  'd_Lynne Ramsay',
#  'd_László Nemes',
#  'd_M. Night Shyamalan',
#  'd_Mabrouk El Mechri',
#  'd_Mac Carter',
#  'd_Maclain Nelson',
#  'd_Malcolm D. Lee',
#  'd_Mandie Fletcher',
#  'd_Marc Forster',
#  'd_Marc Webb',
#  'd_Marcus Dunstan',
#  'd_Marcus Nispel',
#  'd_Maren Ade',
#  'd_Marielle Heller',
#  'd_Mark Andrews',
#  'd_Mark Atkins',
#  'd_Mark Burton',
#  'd_Mark Elijah Rosenberg',
#  'd_Mark Mylod',
#  'd_Mark Neveldine',
#  'd_Mark Romanek',
#  'd_Mark Steven Johnson',
#  'd_Mark Waters',
#  'd_Martin Campbell',
#  'd_Martin McDonagh',
#  'd_Martin Owen',
#  'd_Martin Scorsese',
#  'd_Martín Rosete',
#  'd_Mary Agnes Donoghue',
#  'd_Maryam Keshavarz',
#  'd_Mateo Gil',
#  'd_Mathieu Amalric',
#  'd_Matt Bettinelli-Olpin',
#  'd_Matt Cooper',
#  'd_Matt Reeves',
#  'd_Matt Ross',
#  'd_Matthew Vaughn',
#  'd_Matthew Warchus',
#  'd_Matthijs van Heijningen Jr.',
#  'd_Max Joseph',
#  'd_Max Nichols',
#  'd_Maxim Korostyshevsky',
#  'd_McG',
#  'd_Meera Menon',
#  'd_Mel Gibson',
#  'd_Michael Almereyda',
#  'd_Michael Apted',
#  'd_Michael Bay',
#  'd_Michael Berry',
#  'd_Michael Buster',
#  'd_Michael Cuesta',
#  'd_Michael Damian',
#  'd_Michael Dougherty',
#  'd_Michael Grandage',
#  'd_Michael Haneke',
#  'd_Michael Hoffman',
#  'd_Michael J. Bassett',
#  'd_Michael Lembeck',
#  'd_Michael Mann',
#  'd_Michael Mohan',
#  'd_Michael Patrick King',
#  'd_Michael Polish',
#  'd_Michael Radford',
#  'd_Michael Sucsy',
#  'd_Michael Tiddes',
#  'd_Michael Winterbottom',
#  'd_Michaël R. Roskam',
#  'd_Michel Franco',
#  'd_Michel Hazanavicius',
#  'd_Mick Jackson',
#  'd_Miguel Arteta',
#  'd_Miguel Sapochnik',
#  'd_Miguel Ángel Vivas',
#  'd_Mikael Håfström',
#  'd_Mike Birbiglia',
#  'd_Mike Cahill',
#  'd_Mike Flanagan',
#  'd_Mike Leigh',
#  'd_Mike McCoy',
#  'd_Mike Mendez',
#  'd_Mike Mills',
#  'd_Mike Mitchell',
#  'd_Mike Newell',
#  'd_Mike Norris',
#  'd_Mike Thurmeier',
#  'd_Mira Nair',
#  'd_Morten Tyldum',
#  'd_Måns Mårlind',
#  'd_Nacho G. Velilla',
#  'd_Nancy Meyers',
#  'd_Nate Parker',
#  'd_Neil Burger',
#  'd_Neil LaBute',
#  'd_Neil Marshall',
#  'd_Neill Blomkamp',
#  'd_Nicholas DiBella',
#  'd_Nicholas Hytner',
#  'd_Nicholas Jarecki',
#  'd_Nicholas Stoller',
#  'd_Nick Cassavetes',
#  'd_Nicolas Pesce',
#  'd_Nicolas Winding Refn',
#  'd_Nicole Holofcener',
#  'd_Niels Arden Oplev',
#  'd_Nigel Cole',
#  'd_Nikolaj Arcel',
#  'd_Nils Gaup',
#  'd_Nima Nourizadeh',
#  'd_Nimród Antal',
#  'd_Noah Baumbach',
#  'd_Ole Bornedal',
#  'd_Oliver Hirschbiegel',
#  'd_Oliver Irving',
#  'd_Oliver Parker',
#  'd_Oliver Stone',
#  'd_Olivier Megaton',
#  'd_Omar Naim',
#  'd_Oren Peli',
#  'd_Osmany Rodriguez',
#  'd_Pablo Berger',
#  'd_Pablo Larraín',
#  'd_Paolo Sorrentino',
#  'd_Pascal Chaumeil',
#  'd_Pascal Laugier',
#  'd_Patricia Riggen',
#  'd_Patrick Brice',
#  'd_Patrick Hughes',
#  'd_Patrick Lussier',
#  'd_Paul Feig',
#  'd_Paul Greengrass',
#  'd_Paul Haggis',
#  'd_Paul Johansson',
#  'd_Paul Leyden',
#  'd_Paul McGuigan',
#  'd_Paul Schrader',
#  'd_Paul Thomas Anderson',
#  'd_Paul Tibbitt',
#  'd_Paul Verhoeven',
#  'd_Paul W.S. Anderson',
#  'd_Paul Weitz',
#  'd_Pedro Almodóvar',
#  'd_Pete Docter',
#  'd_Pete Travis',
#  'd_Peter Atencio',
#  'd_Peter Berg',
#  'd_Peter Billingsley',
#  'd_Peter Hedges',
#  'd_Peter Ho-Sun Chan',
#  'd_Peter Jackson',
#  'd_Peter Landesman',
#  'd_Peter Lepeniotis',
#  'd_Peter Lord',
#  'd_Peter Ramsey',
#  'd_Peter Sattler',
#  'd_Peter Segal',
#  'd_Peter Sohn',
#  'd_Peter Sollett',
#  'd_Peyton Reed',
#  'd_Phil Claydon',
#  'd_Phil Dorling',
#  'd_Phil Lord',
#  'd_Philip Seymour Hoffman',
#  'd_Philippe Falardeau',
#  'd_Phillip Noyce',
#  'd_Phyllida Lloyd',
#  'd_Pierre Coffin',
#  'd_Pierre Morel',
#  'd_Powell Robinson',
#  'd_Quentin Tarantino',
#  'd_R.J. Cutler',
#  'd_RZA',
#  'd_Raja Gosnell',
#  'd_Ralph Fiennes',
#  'd_Randall Miller',
#  'd_Randall Wallace',
#  'd_Rawson Marshall Thurber',
#  'd_Raymond De Felitta',
#  'd_Reed Morano',
#  'd_Renny Harlin',
#  'd_Rian Johnson',
#  'd_Ric Roman Waugh',
#  'd_Rich Christiano',
#  'd_Rich Moore',
#  'd_Richard Bates Jr.',
#  'd_Richard Curtis',
#  'd_Richard LaGravenese',
#  'd_Richard Linklater',
#  'd_Richard Ramsey',
#  'd_Richard Tanne',
#  'd_Rick Alverson',
#  'd_Rick Famuyiwa',
#  'd_Ridley Scott',
#  'd_Rob Cohen',
#  'd_Rob Connolly',
#  'd_Rob Epstein',
#  'd_Rob Letterman',
#  'd_Rob Marshall',
#  'd_Rob Minkoff',
#  'd_Rob Reiner',
#  'd_Rob Thomas',
#  'd_Rob Zombie',
#  'd_Robbie Pickering',
#  'd_Robert Ben Garant',
#  'd_Robert Lorenz',
#  'd_Robert Luketic',
#  'd_Robert Rodriguez',
#  'd_Robert Schwentke',
#  'd_Robert Stromberg',
#  'd_Robert Zemeckis',
#  'd_Roberts Gannaway',
#  'd_Rod Lurie',
#  'd_Rodrigo Cortés',
#  'd_Roger Donaldson',
#  'd_Roger Michell',
#  'd_Roland Emmerich',
#  'd_Roland Joffé',
#  'd_Roman Atwood',
#  'd_Roman Polanski',
#  'd_Ron Clements',
#  'd_Ron Howard',
#  'd_Ross Katz',
#  'd_Ross Partridge',
#  'd_Ruairi Robinson',
#  'd_Ruben Fleischer',
#  'd_Ruben Östlund',
#  'd_Rupert Goold',
#  'd_Rupert Sanders',
#  'd_Rupert Wyatt',
#  'd_Ry Russo-Young',
#  'd_Ryan Coogler',
#  'd_Ryan Little',
#  'd_Ryan Murphy',
#  'd_Ryan Smith',
#  'd_Ryon Baxter',
#  'd_Sacha Gervasi',
#  'd_Salim Akil',
#  'd_Sam Esmail',
#  'd_Sam Jaeger',
#  'd_Sam Levinson',
#  'd_Sam Liu',
#  'd_Sam Mendes',
#  'd_Sam Miller',
#  'd_Sam Taylor-Johnson',
#  'd_Samuel Bayer',
#  'd_Sarah Gavron',
#  'd_Sarah Smith',
#  'd_Scott Cooper',
#  'd_Scott Derrickson',
#  'd_Scott Frank',
#  'd_Scott Hicks',
#  'd_Scott Mann',
#  'd_Scott Speer',
#  'd_Scott Stewart',
#  'd_Scott Waugh',
#  'd_Sean Anders',
#  'd_Sean Baker',
#  'd_Sean Durkin',
#  'd_Sean Ellis',
#  'd_Sean McNamara',
#  'd_Sebastián Cordero',
#  'd_Sebastián Silva',
#  'd_Seth Gordon',
#  'd_Seth MacFarlane',
#  'd_Shana Feste',
#  'd_Shane Abbess',
#  'd_Shane Black',
#  'd_Sharon Maguire',
#  'd_Shawn Crahan',
#  'd_Shawn Levy',
#  'd_Simon Barrett',
#  'd_Simon Curtis',
#  'd_Simon Wells',
#  'd_Simon West',
#  'd_Sngmoo Lee',
#  'd_Sofia Coppola',
#  'd_Spike Jonze',
#  'd_Spike Lee',
#  'd_Stacie Passon',
#  'd_Stephen Chbosky',
#  'd_Stephen Daldry',
#  'd_Stephen Elliott',
#  'd_Stephen Frears',
#  'd_Stephen Gaghan',
#  'd_Stephen Hopkins',
#  'd_Stephen Milburn Anderson',
#  'd_Steve Antin',
#  'd_Steve Carr',
#  'd_Steve Martino',
#  'd_Steve McQueen',
#  'd_Steve Pink',
#  'd_Steve Taylor',
#  'd_Steven Brill',
#  'd_Steven C. Miller',
#  'd_Steven Caple Jr.',
#  'd_Steven Knight',
#  'd_Steven Quale',
#  'd_Steven R. Monroe',
#  'd_Steven Soderbergh',
#  'd_Steven Spielberg',
#  'd_Stewart Hendler',
#  'd_Stiles White',
#  'd_Stuart Zicherman',
#  'd_Susanna Fogel',
#  'd_Susanna White',
#  'd_Sylvain White',
#  'd_Sylvester Stallone',
#  'd_T.C. Christensen',
#  'd_Taika Waititi',
#  'd_Takashi Miike',
#  'd_Tarsem Singh',
#  'd_Tate Taylor',
#  'd_Tatia Pilieva',
#  'd_Taylor Hackford',
#  'd_Terrence Malick',
#  'd_Thea Sharrock',
#  'd_Theodore Melfi',
#  'd_Thomas Carter',
#  'd_Thomas Vinterberg',
#  'd_Thor Freudenthal',
#  'd_Ti West',
#  'd_Tim Burton',
#  'd_Tim Garrick',
#  'd_Tim Johnson',
#  'd_Tim Miller',
#  'd_Tim Story',
#  'd_Timo Vuorensola',
#  'd_Timothy A. Chey',
#  'd_Timothy Hines',
#  'd_Timur Bekmambetov',
#  'd_Tod Williams',
#  'd_Todd Haynes',
#  'd_Todd Lincoln',
#  'd_Todd Louiso',
#  'd_Todd Phillips',
#  'd_Todd Solondz',
#  'd_Todd Strauss-Schulson',
#  'd_Tom Ford',
#  'd_Tom Gormican',
#  'd_Tom Hanks',
#  'd_Tom Hooper',
#  'd_Tom McCarthy',
#  'd_Tom McGrath',
#  'd_Tom Tykwer',
#  'd_Tom Vaughan',
#  'd_Tomm Moore',
#  'd_Tommy Lee Jones',
#  'd_Tommy Wirkola',
#  'd_Tony Gilroy',
#  'd_Tony Goldwyn',
#  'd_Tony McNamara',
#  'd_Tony Scott',
#  'd_Travis Cluff',
#  'd_Travis Knight',
#  'd_Trey Haley',
#  'd_Trish Sie',
#  'd_Tyler Perry',
#  'd_Tyler Shields',
#  'd_Vic Armstrong',
#  'd_Vince Offer',
#  'd_Vincent Kesteloot',
#  'd_Wally Pfister',
#  'd_Walter Salles',
#  ...]

# %%
X = df_clean.drop(['url', ])
# Out:
# 164      10001982
# 1175     10003827
# 100     100038390
# 418        100040
# 679         10020
# 282      10021215
# 1023       100268
# 111        100316
# 797        100847
# 265      10106872
# 883      10177257
# 446      10203437
# 827       1021768
# 516        102351
# 1231    102665981
# 940        102706
# 54       10278225
# 280      10283250
# 1146     10288932
# 145     103261464
# 143      10326356
# 488         10340
# 544         10367
# 1120     10408176
# 650         10422
# 76      104352905
# 129      10441000
# 1049     10470143
# 991        105005
# 816      10515659
#           ...
# 661           NaN
# 667           NaN
# 669           NaN
# 683           NaN
# 684           NaN
# 690           NaN
# 697           NaN
# 706           NaN
# 739           NaN
# 750           NaN
# 772           NaN
# 802           NaN
# 805           NaN
# 826           NaN
# 877           NaN
# 908           NaN
# 913           NaN
# 918           NaN
# 924           NaN
# 926           NaN
# 958           NaN
# 965           NaN
# 981           NaN
# 986           NaN
# 990           NaN
# 1014          NaN
# 1045          NaN
# 1086          NaN
# 1164          NaN
# 1174          NaN
# Name: opening, Length: 1264, dtype: object

# %%
ary = np.arange(0,100,0.01)

# %%
# %%timeit
ary2 = ary*2 - 0.01
# Out:
# The slowest run took 24.38 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100000 loops, best of 3: 11.4 µs per loop

# %%
ary3 =
# Out:
# array([ -1.00000000e-02,   1.00000000e-02,   3.00000000e-02, ...,
#          1.99930000e+02,   1.99950000e+02,   1.99970000e+02])

# %%
import urllib.parse

# %%
urllib.parse.quote('This is the film (2009)')
# Out:
# 'This%20is%20the%20film%20%282009%29'

# %%
l = [1,2,3,4]

# %%
l.split()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-107-e46f1139e64a> in <module>()
# ----> 1 l.split()
#
# AttributeError: 'list' object has no attribute 'split'
